# %%
from collections import Counter
import numpy as np
import pandas as pd

# %%
import pandas as pd
import glob
import os

# merging the files
joined_files = os.path.join("C:/Users/yodar/Desktop/Info retrieval/WORD COUNT", "*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)
  
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)

# %%
df
# Out:
#        Unnamed: 0            id         username geo    created_at  \
# 0               0  1.510000e+18       Envisager_      1.648570e+12
# 1               1  1.510000e+18        23ABCNews      1.648570e+12
# 2               2  1.510000e+18   BsiflingTrades      1.648570e+12
# 3               3  1.510000e+18   CloseHouseGolf      1.648570e+12
# 4               4  1.510000e+18       GadgetFlow      1.648570e+12
# ...           ...           ...              ...  ..           ...
# 92468        2454  1.490000e+18  autocarindiamag      1.643430e+12
# 92469        2455  1.490000e+18         Radio702      1.643430e+12
# 92470        2456  1.490000e+18      ReutersAsia      1.643420e+12
# 92471        2457  1.490000e+18       ReutersBiz      1.643420e+12
# 92472        2458  1.490000e+18          Reuters      1.643420e+12
#
#                        date  \
# 0      2022-03-29T23:49:40Z
# 1      2022-03-29T23:45:26Z
# 2      2022-03-29T23:31:36Z
# 3      2022-03-29T23:30:05Z
# ...

# %% [markdown]
# # Number of records

# %%
len(df)
# Out:
# 92473

# %% [markdown]
# # Number of words

# %%
#count words for each column

df['word_count'] = df['tweet'].str.count(' ') + 1

# %%
Total = df['word_count'].sum()
print (Total)
# Out:
# 2198841

# %% [markdown]
# # Number of unique words

# %%
x = Counter(" ".join(df['tweet'].str.lower().values.tolist()).split(" "))

# %%
len(x)
# Out:
# 214151
